# %%
# Importing libraries

# For the PyTorch neural network:
import torch
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
from torch.nn.modules.loss import BCEWithLogitsLoss

# For plots
import matplotlib.pyplot as plt

# Numpy is a handy way to deal with matrices and tensors
import numpy as np

# Utilities for preparing the dataset
import os
from PIL import Image


import torch
torch.manual_seed(5) # this makes the training reproducible: every training have the same initialization

from torchviz import make_dot

from torch.utils.data import DataLoader, TensorDataset

from torchview import draw_graph

import graphviz

# %%
import my_utilities as fun

# %%
parasitized_images=fun.load_images("../Dataset/parasitized/")
uninfected_images=fun.load_images('../Dataset/uninfected/')
model_folder="3RotationWithoutEntaglementModelResults/"
model_name="3RWEMR150Epochs"
nEp=150
# Out:
# mioDataSet/parasitized/
# mioDataSet/uninfected/

# %%
#split data in 2 subsets: the first one is used for training and second one for validation
#also return 2 vectors (trainLabels and validationLabels) containing ones if the images is parasitized 0 else
#note that the last parameter is used to shuffle data
trainSet,valSet,trainLabels,validationLabels=fun.create_2_subsets(parasitized_images,uninfected_images,42)

#convert data to Torch tensor type (annoying but necessary)
trainSetTorch,validationSetTorch,trainLabelsTorch,validationLabelsTorch=fun.data_to_torch(trainSet,valSet,trainLabels,validationLabels)

#convert dato to dataLoader type
dataloader_train,dataloader_val=fun.create_dataloader_from_torchdata(trainSetTorch, trainLabelsTorch,validationSetTorch, validationLabelsTorch)

# %%
#Classic model
# Defining a Net class, Module is imported from torch.nn and it is the parent class
class Net(Module): 
    #init is constructor method in phyton, self represents the instance
    def __init__(self):
        super(Net, self).__init__()

        # Defining layers that are specific of the CNN
        self.cnn_layers = Sequential(
            # Defining a 2D convolution layer
            Conv2d(1, 5, kernel_size=5, stride=3, padding=4),
            BatchNorm2d(5), # A normalization layer (not important to study)
            ReLU(inplace=True), # The activation funcion (Rectified Linear Unit)
            MaxPool2d(kernel_size=2, stride=2), # Pooling layer
            # Defining another 2D convolution layer
            Conv2d(5, 5, kernel_size=3, stride=1, padding=1),
            BatchNorm2d(5),
            ReLU(inplace=True),
            MaxPool2d(kernel_size=2, stride=2),
        )
        self.linear=Sequential(
            Linear(125,10),
            ReLU(inplace=True),
            Linear(10, 2),
            #ReLU(inplace=True),
            )
        
        # Defining a normal layer of neurons (usually called Linear, Dense, or similar)
        self.linear2 = Sequential(
            #Linear(125, 10),
            #ReLU(inplace=True),
            # Dropout(0.1),
            #Linear(10, 4),
            #ReLU(inplace=True),
            Linear(2, 1),
            
            #ReLU(inplace=True),
            # Dropout(0.1),
        )

    # Defining the forward pass    
    def forward(self, x):
        # First, applying all the convolutional stuff
        x = self.cnn_layers(x)
        x = x.view(x.size(0), -1) # not important
        # Second applying all the linear layers (only one for now)
       
        x = self.linear(x)
        x = self.linear2(x)
        #x = Linear(2,1)(x)
        return x

# %%
# defining the model
model = Net()
#print(model)
# defining the optimizer
optimizer = Adam(model.parameters(), lr=0.0001)
# defining the loss function
loss_function = BCEWithLogitsLoss()

# %%
# defining the training function
def train(epoch, valSet, validationLabels, trainSet, trainLabels):
    for id_batch, (x_batch, y_batch) in enumerate(dataloader_train): #enumerate method adds counter to an iterable and returns it. The returned object is an enumerate object
        #model(x) invokes the call method wich calls the forward method
        #in y_batch there is the label
        y_batch_prediction = model(x_batch)          
        y_batch = torch.reshape(y_batch, [y_batch.shape[0], 1])
        loss_train = loss_function(y_batch_prediction, y_batch)
        # train_losses.append(loss_train.detach().numpy())
        
        #clear gradients
        optimizer.zero_grad()
        
        #backpropagation, compute gradients
        loss_train.backward()
        
        #apply gradient
        optimizer.step()
   
    y_pred = model(valSet)
    validationLabels = torch.reshape(validationLabels, [validationLabels.shape[0], 1])
    loss_val = loss_function(y_pred, validationLabels)
    val_losses.append(loss_val.detach().numpy())

    y_pred = model(trainSet)
    trainLabels = torch.reshape(trainLabels, [trainLabels.shape[0], 1])
    loss_train = loss_function(y_pred, trainLabels)
    train_losses.append(loss_train.detach().numpy())

# %%
# defining the number of epochs
n_epochs = nEp
# empty list to store training losses
train_losses = []
accuracyTrainLosses=[]
# empty list to store validation losses
val_losses = []
# training the model
comodo=0
for epoch in range(n_epochs):
    comodo=comodo+1
    train(epoch, validationSetTorch, validationLabelsTorch, trainSetTorch, trainLabelsTorch)
    print(train_losses[epoch])
    scores_train = torch.sigmoid(model(trainSetTorch))[:,0]
    predictions_train = scores_train > 0.5
    accuracy_train = (predictions_train == trainLabelsTorch).sum()/ trainLabelsTorch.shape[0]
    print("accuracy on training set for epoch number "+str(comodo)+" ", accuracy_train.numpy())
    accuracyTrainLosses.append(accuracy_train.numpy())
# Out:
# 0.69600844
# accuracy on training set for epoch number 1  0.505
# 0.69545335
# accuracy on training set for epoch number 2  0.505
# 0.69484633
# accuracy on training set for epoch number 3  0.505
# 0.6935205
# accuracy on training set for epoch number 4  0.505
# 0.69124585
# accuracy on training set for epoch number 5  0.50625
# 0.68902457
# accuracy on training set for epoch number 6  0.53
# 0.6872626
# accuracy on training set for epoch number 7  0.565
# 0.68602663
# accuracy on training set for epoch number 8  0.565
# 0.68515795
# accuracy on training set for epoch number 9  0.57125
# 0.68425006
# accuracy on training set for epoch number 10  0.58375
# 0.6834833
# accuracy on training set for epoch number 11  0.5975
# 0.6826275
# accuracy on training set for epoch number 12  0.6025
# 0.68177795
# accuracy on training set for epoch number 13  0.61375
# 0.6809722
# accuracy on training set for epoch number 14  0.62125
# 0.6801752
# accuracy on training set for epoch number 15  0.61625
# 0.67924
# accuracy on training set for epoch number 16  0.62375
# 0.6782301
# accuracy on training set for epoch number 17  0.6275
# 0.6771172
# accuracy on training set for epoch number 18  0.63625
# 0.67576236
# accuracy on training set for epoch number 19  0.6375
# 0.6741985
# accuracy on training set for epoch number 20  0.64
# 0.6723631
# accuracy on training set for epoch number 21  0.64625
# 0.6703685
# accuracy on training set for epoch number 22  0.645
# 0.6682349
# accuracy on training set for epoch number 23  0.65125
# 0.66591966
# accuracy on training set for epoch number 24  0.6525
# 0.6630437
# accuracy on training set for epoch number 25  0.65375
# 0.660163
# accuracy on training set for epoch number 26  0.65875
# 0.6565311
# accuracy on training set for epoch number 27  0.665
# 0.6526873
# accuracy on training set for epoch number 28  0.67
# 0.64918894
# accuracy on training set for epoch number 29  0.67125
# 0.645331
# accuracy on training set for epoch number 30  0.67375
# 0.64148134
# accuracy on training set for epoch number 31  0.67625
# 0.6372892
# accuracy on training set for epoch number 32  0.68
# 0.6331296
# accuracy on training set for epoch number 33  0.68375
# 0.6290001
# accuracy on training set for epoch number 34  0.6925
# 0.6245839
# accuracy on training set for epoch number 35  0.69125
# 0.6203296
# accuracy on training set for epoch number 36  0.7025
# 0.61605346
# accuracy on training set for epoch number 37  0.70375
# 0.61193377
# accuracy on training set for epoch number 38  0.7025
# 0.60772777
# accuracy on training set for epoch number 39  0.70875
# 0.6034633
# accuracy on training set for epoch number 40  0.71125
# 0.59927756
# accuracy on training set for epoch number 41  0.7125
# 0.5949189
# accuracy on training set for epoch number 42  0.7175
# 0.59075576
# accuracy on training set for epoch number 43  0.72625
# 0.58639425
# accuracy on training set for epoch number 44  0.7275
# 0.58150685
# accuracy on training set for epoch number 45  0.7325
# 0.5769349
# accuracy on training set for epoch number 46  0.735
# 0.57205176
# accuracy on training set for epoch number 47  0.74
# 0.5670478
# accuracy on training set for epoch number 48  0.7425
# 0.5632772
# accuracy on training set for epoch number 49  0.74375
# 0.5576077
# accuracy on training set for epoch number 50  0.74875
# 0.5539331
# accuracy on training set for epoch number 51  0.75375
# 0.5481878
# accuracy on training set for epoch number 52  0.7575
# 0.5441401
# accuracy on training set for epoch number 53  0.7625
# 0.53898734
# accuracy on training set for epoch number 54  0.7625
# 0.53499025
# accuracy on training set for epoch number 55  0.76625
# 0.529954
# accuracy on training set for epoch number 56  0.77625
# 0.52555245
# accuracy on training set for epoch number 57  0.7725
# 0.5207899
# accuracy on training set for epoch number 58  0.7825
# 0.519954
# accuracy on training set for epoch number 59  0.77875
# 0.515471
# accuracy on training set for epoch number 60  0.76625
# 0.50787485
# accuracy on training set for epoch number 61  0.78875
# 0.5041082
# accuracy on training set for epoch number 62  0.78375
# 0.49982575
# accuracy on training set for epoch number 63  0.78
# 0.49525845
# accuracy on training set for epoch number 64  0.79
# 0.49123615
# accuracy on training set for epoch number 65  0.78625
# 0.48930445
# accuracy on training set for epoch number 66  0.78875
# 0.48481885
# accuracy on training set for epoch number 67  0.785
# 0.4792797
# accuracy on training set for epoch number 68  0.79125
# 0.475244
# accuracy on training set for epoch number 69  0.7975
# 0.48134202
# accuracy on training set for epoch number 70  0.7725
# 0.47077584
# accuracy on training set for epoch number 71  0.795
# 0.46617988
# accuracy on training set for epoch number 72  0.7925
# 0.46139935
# accuracy on training set for epoch number 73  0.79875
# 0.45756438
# accuracy on training set for epoch number 74  0.8025
# 0.4542948
# accuracy on training set for epoch number 75  0.805
# 0.45126548
# accuracy on training set for epoch number 76  0.8025
# 0.44802997
# accuracy on training set for epoch number 77  0.805
# 0.44525266
# accuracy on training set for epoch number 78  0.80125
# 0.442108
# accuracy on training set for epoch number 79  0.81375
# 0.43824184
# accuracy on training set for epoch number 80  0.81125
# 0.43491754
# accuracy on training set for epoch number 81  0.81
# 0.43373138
# accuracy on training set for epoch number 82  0.80125
# 0.4295038
# accuracy on training set for epoch number 83  0.8
# 0.42589122
# accuracy on training set for epoch number 84  0.8025
# 0.4219738
# accuracy on training set for epoch number 85  0.8125
# 0.4192028
# accuracy on training set for epoch number 86  0.8075
# 0.41598183
# accuracy on training set for epoch number 87  0.81625
# 0.41760388
# accuracy on training set for epoch number 88  0.8125
# 0.41001645
# accuracy on training set for epoch number 89  0.8225
# 0.40708286
# accuracy on training set for epoch number 90  0.82125
# 0.40417275
# accuracy on training set for epoch number 91  0.825
# 0.40281433
# accuracy on training set for epoch number 92  0.83
# 0.40074006
# accuracy on training set for epoch number 93  0.8375
# 0.39589813
# accuracy on training set for epoch number 94  0.8275
# 0.39860976
# accuracy on training set for epoch number 95  0.82375
# 0.3968176
# accuracy on training set for epoch number 96  0.83875
# 0.38875222
# accuracy on training set for epoch number 97  0.8325
# 0.38603032
# accuracy on training set for epoch number 98  0.83625
# 0.38353032
# accuracy on training set for epoch number 99  0.83875
# 0.38081032
# accuracy on training set for epoch number 100  0.8375
# 0.37896693
# accuracy on training set for epoch number 101  0.835
# 0.3774005
# accuracy on training set for epoch number 102  0.83625
# 0.37891275
# accuracy on training set for epoch number 103  0.82625
# 0.3736537
# accuracy on training set for epoch number 104  0.835
# 0.37292096
# accuracy on training set for epoch number 105  0.85
# 0.379501
# accuracy on training set for epoch number 106  0.825
# 0.36372146
# accuracy on training set for epoch number 107  0.8525
# 0.36456603
# accuracy on training set for epoch number 108  0.85625
# 0.36638024
# accuracy on training set for epoch number 109  0.85
# 0.35839555
# accuracy on training set for epoch number 110  0.84125
# 0.35574338
# accuracy on training set for epoch number 111  0.845
# 0.36583835
# accuracy on training set for epoch number 112  0.8275
# 0.35275114
# accuracy on training set for epoch number 113  0.8575
# 0.35969573
# accuracy on training set for epoch number 114  0.8325
# 0.3471414
# accuracy on training set for epoch number 115  0.86
# 0.34459317
# accuracy on training set for epoch number 116  0.86
# 0.34347525
# accuracy on training set for epoch number 117  0.8525
# 0.34516993
# accuracy on training set for epoch number 118  0.8675
# 0.3549027
# accuracy on training set for epoch number 119  0.82625
# 0.33804017
# accuracy on training set for epoch number 120  0.86
# 0.3367954
# accuracy on training set for epoch number 121  0.855
# 0.336954
# accuracy on training set for epoch number 122  0.84875
# 0.33278793
# accuracy on training set for epoch number 123  0.85875
# 0.33014077
# accuracy on training set for epoch number 124  0.86375
# 0.330092
# accuracy on training set for epoch number 125  0.85625
# 0.3266142
# accuracy on training set for epoch number 126  0.86125
# 0.32666898
# accuracy on training set for epoch number 127  0.8675
# 0.32318282
# accuracy on training set for epoch number 128  0.86125
# 0.32416016
# accuracy on training set for epoch number 129  0.855
# 0.33212066
# accuracy on training set for epoch number 130  0.8425
# 0.32276934
# accuracy on training set for epoch number 131  0.87375
# 0.31672016
# accuracy on training set for epoch number 132  0.86375
# 0.32350597
# accuracy on training set for epoch number 133  0.87875
# 0.3131686
# accuracy on training set for epoch number 134  0.86875
# 0.31620955
# accuracy on training set for epoch number 135  0.85375
# 0.3098918
# accuracy on training set for epoch number 136  0.86375
# 0.31062838
# accuracy on training set for epoch number 137  0.8575
# 0.3076193
# accuracy on training set for epoch number 138  0.87
# 0.30652913
# accuracy on training set for epoch number 139  0.86
# 0.30444542
# accuracy on training set for epoch number 140  0.87125

# %%
#PARTE QUANTISTICA
#------------------------------------------------------------------------------------------------------------------------

from qiskit import QuantumCircuit
from qiskit.utils import algorithm_globals
from qiskit.circuit import ParameterVector
from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector
from numpy import pi
import time

def create_qnn():
    feature_map = ZZFeatureMap(3)
    
    paramToTrain = ParameterVector('par', 3)
    #print(param1)
    
    qc = QuantumCircuit(3)
    qc.rx(paramToTrain[1],1)
    qc.ry(paramToTrain[0],0)
    qc.ry(paramToTrain[2],2)
    qc.compose(feature_map, inplace=True)
    print(qc)
    qc.draw('mpl')
    # REMEMBER TO SET input_gradients=True FOR ENABLING HYBRID GRADIENT BACKPROP
    qnn = EstimatorQNN(
        circuit=qc,
        input_params=feature_map.parameters,
        weight_params=paramToTrain ,
        input_gradients=True,
    )
    return qnn

# %%
class Net(Module):   
    def __init__(self):
        super(Net, self).__init__()

        # Defining layers that are specific of the CNN
        self.cnn_layers = Sequential(
             # Defining a 2D convolution layer
            Conv2d(1, 5, kernel_size=5, stride=3, padding=4),
            BatchNorm2d(5), # A normalization layer (not important to study)
            ReLU(inplace=True), # The activation funcion (Rectified Linear Unit)
            MaxPool2d(kernel_size=2, stride=2), # Pooling layer
            # Defining another 2D convolution layer
            Conv2d(5, 5, kernel_size=3, stride=1, padding=1),
            BatchNorm2d(5),
            ReLU(inplace=True),
            MaxPool2d(kernel_size=2, stride=2),
        )

        # Defining a normal layer of neurons (usually called Linear, Dense, or similar)
        self.linear_layers = Sequential(
            Linear(125, 10),
            ReLU(inplace=True),
            # Dropout(0.1),
            Linear(10, 3),
            #ReLU(inplace=True),
            # Dropout(0.1),
        )
        self.qnn = TorchConnector(qnn) 
        self.linear_layers2 = Sequential(
            Linear(1,1),
        )

    # Defining the forward pass    
    def forward(self, x):
        # First, applying all the convolutional stuff
        x = self.cnn_layers(x)
        x = x.view(x.size(0), -1) # not important
        # Second applying all the linear layers (only one for now)
        x = self.linear_layers(x)
        x = self.qnn(x)
        #x = self.linear_layers2(x)
        return x

# %%
# defining the model
qnn=create_qnn()

model4 = Net()
graficoModelloIbrido = draw_graph(model4, input_size=(1, 1, 64, 64), save_graph= True, filename = "cnn_architecture")
#show the architecture
graficoModelloIbrido.visual_graph
print(model4)
# defining the optimizer
optimizer = Adam(model4.parameters(), lr=0.0001)
# defining the loss function
criterion = BCEWithLogitsLoss()
# Out:
# (process:20648): Pango-WARNING **: 00:51:10.671: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.
# Net(
#   (cnn_layers): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(5, 5), stride=(3, 3), padding=(4, 4))
#     (1): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (linear_layers): Sequential(
#     (0): Linear(in_features=125, out_features=10, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=10, out_features=3, bias=True)
#   )
#   (qnn): TorchConnector()
#   (linear_layers2): Sequential(
#     (0): Linear(in_features=1, out_features=1, bias=True)
#   )
# )

# %%
# defining the number of epochs
epochs = nEp
# empty list to store training losses
train_lossesq = []
# empty list to store validation losses
val_lossesq = []
accuracyTrainLossesq=[]
toc=0
tic=0
# training the model
for epoch in range(epochs):
    print("epoca")
    total_loss=[]
    tic=time.perf_counter()
    for id_batch, (data, label) in enumerate(dataloader_train):
        optimizer.zero_grad(set_to_none=True)
        nComodo=nComodo+1
        output=model4(data)
        label=torch.reshape(label,[label.shape[0], 1])
        loss=criterion(output,label)
        loss.backward()
        optimizer.step()
        total_loss.append(loss.item())
    toc = time.perf_counter()
    print(f" time :  {toc - tic:0.4f} seconds")
    train_lossesq.append(sum(total_loss)/len(total_loss))
    print("Training [{:.0f}%]\tLoss: {:.4f}".format(100.0 * (epoch + 1) / epochs, train_lossesq[-1]))
    y_pred = model4(validationSetTorch)
    validationLabels = torch.reshape(validationLabelsTorch, [validationLabelsTorch.shape[0], 1])
    loss_val = loss_function(y_pred, validationLabels)
    val_lossesq.append(loss_val.detach().numpy())
    scores_train = torch.sigmoid(model4(trainSetTorch))[:,0]
    predictions_train = scores_train > 0.5
    accuracy_train = (predictions_train == trainLabelsTorch).sum()/ trainLabelsTorch.shape[0]
    print("accuracy on training set for epoch number "+str(epoch)+" ", accuracy_train.numpy())
    accuracyTrainLossesq.append(accuracy_train.numpy())
# Out:
# epoca
# 0.0
#  time :  43.8762 seconds
# Training [1%]	Loss: 0.6928
# accuracy on training set for epoch number 1  0.51125
# epoca
# 1.0
#  time :  4.7846 seconds
# Training [1%]	Loss: 0.6883
# accuracy on training set for epoch number 2  0.52
# epoca
# 2.0
#  time :  5.2967 seconds
# Training [2%]	Loss: 0.6855
# accuracy on training set for epoch number 3  0.565
# epoca
# 3.0
#  time :  5.1516 seconds
# Training [3%]	Loss: 0.6832
# accuracy on training set for epoch number 4  0.605
# epoca
# 4.0
#  time :  5.6623 seconds
# Training [4%]	Loss: 0.6809
# accuracy on training set for epoch number 5  0.61375
# epoca
# 5.0
#  time :  5.3404 seconds
# Training [4%]	Loss: 0.6791
# accuracy on training set for epoch number 6  0.6275
# epoca
# 6.0
#  time :  4.9490 seconds
# Training [5%]	Loss: 0.6769
# accuracy on training set for epoch number 7  0.635
# epoca
# 7.0
#  time :  4.4509 seconds
# Training [6%]	Loss: 0.6741
# accuracy on training set for epoch number 8  0.63125
# epoca
# 8.0
#  time :  4.8686 seconds
# Training [6%]	Loss: 0.6729
# accuracy on training set for epoch number 9  0.6425
# epoca
# 9.0
#  time :  4.5475 seconds
# Training [7%]	Loss: 0.6712
# accuracy on training set for epoch number 10  0.64375
# epoca
# 10.0
#  time :  4.9404 seconds
# Training [8%]	Loss: 0.6696
# accuracy on training set for epoch number 11  0.6475
# epoca
# 11.0
#  time :  4.7392 seconds
# Training [9%]	Loss: 0.6689
# accuracy on training set for epoch number 12  0.6475
# epoca
# 12.0
#  time :  4.5217 seconds
# Training [9%]	Loss: 0.6662
# accuracy on training set for epoch number 13  0.65625
# epoca
# 13.0
#  time :  4.7349 seconds
# Training [10%]	Loss: 0.6638
# accuracy on training set for epoch number 14  0.655
# epoca
# 14.0
#  time :  4.6055 seconds
# Training [11%]	Loss: 0.6627
# accuracy on training set for epoch number 15  0.6575
# epoca
# 15.0
#  time :  4.9025 seconds
# Training [11%]	Loss: 0.6597
# accuracy on training set for epoch number 16  0.65875
# epoca
# 16.0
#  time :  4.8392 seconds
# Training [12%]	Loss: 0.6583
# accuracy on training set for epoch number 17  0.65625
# epoca
# 17.0
#  time :  4.8706 seconds
# Training [13%]	Loss: 0.6564
# accuracy on training set for epoch number 18  0.65875
# epoca
# 18.0
#  time :  4.8219 seconds
# Training [14%]	Loss: 0.6554
# accuracy on training set for epoch number 19  0.65875
# epoca
# 19.0
#  time :  5.3792 seconds
# Training [14%]	Loss: 0.6518
# accuracy on training set for epoch number 20  0.67
# epoca
# 20.0
#  time :  4.3094 seconds
# Training [15%]	Loss: 0.6506
# accuracy on training set for epoch number 21  0.665
# epoca
# 21.0
#  time :  4.4227 seconds
# Training [16%]	Loss: 0.6482
# accuracy on training set for epoch number 22  0.66625
# epoca
# 22.0
#  time :  4.7716 seconds
# Training [16%]	Loss: 0.6459
# accuracy on training set for epoch number 23  0.6675
# epoca
# 23.0
#  time :  4.6871 seconds
# Training [17%]	Loss: 0.6430
# accuracy on training set for epoch number 24  0.66875
# epoca
# 24.0
#  time :  4.6636 seconds
# Training [18%]	Loss: 0.6415
# accuracy on training set for epoch number 25  0.6725
# epoca
# 25.0
#  time :  4.6005 seconds
# Training [19%]	Loss: 0.6390
# accuracy on training set for epoch number 26  0.68
# epoca
# 26.0
#  time :  4.3522 seconds
# Training [19%]	Loss: 0.6378
# accuracy on training set for epoch number 27  0.68125
# epoca
# 27.0
#  time :  4.4162 seconds
# Training [20%]	Loss: 0.6353
# accuracy on training set for epoch number 28  0.6825
# epoca
# 28.0
#  time :  4.3911 seconds
# Training [21%]	Loss: 0.6322
# accuracy on training set for epoch number 29  0.6825
# epoca
# 29.0
#  time :  4.4573 seconds
# Training [21%]	Loss: 0.6289
# accuracy on training set for epoch number 30  0.69125
# epoca
# 30.0
#  time :  4.4724 seconds
# Training [22%]	Loss: 0.6262
# accuracy on training set for epoch number 31  0.7
# epoca
# 31.0
#  time :  4.3892 seconds
# Training [23%]	Loss: 0.6254
# accuracy on training set for epoch number 32  0.68
# epoca
# 32.0
#  time :  4.3117 seconds
# Training [24%]	Loss: 0.6189
# accuracy on training set for epoch number 33  0.7125
# epoca
# 33.0
#  time :  4.3556 seconds
# Training [24%]	Loss: 0.6195
# accuracy on training set for epoch number 34  0.71
# epoca
# 34.0
#  time :  4.4738 seconds
# Training [25%]	Loss: 0.6161
# accuracy on training set for epoch number 35  0.72375
# epoca
# 35.0
#  time :  4.3787 seconds
# Training [26%]	Loss: 0.6138
# accuracy on training set for epoch number 36  0.72125
# epoca
# 36.0
#  time :  4.6267 seconds
# Training [26%]	Loss: 0.6121
# accuracy on training set for epoch number 37  0.725
# epoca
# 37.0
#  time :  4.4042 seconds
# Training [27%]	Loss: 0.6081
# accuracy on training set for epoch number 38  0.735
# epoca
# 38.0
#  time :  4.4765 seconds
# Training [28%]	Loss: 0.6076
# accuracy on training set for epoch number 39  0.73
# epoca
# 39.0
#  time :  4.3615 seconds
# Training [29%]	Loss: 0.6036
# accuracy on training set for epoch number 40  0.74
# epoca
# 40.0
#  time :  4.4169 seconds
# Training [29%]	Loss: 0.5995
# accuracy on training set for epoch number 41  0.73875
# epoca
# 41.0
#  time :  4.3048 seconds
# Training [30%]	Loss: 0.5965
# accuracy on training set for epoch number 42  0.725
# epoca
# 42.0
#  time :  4.4162 seconds
# Training [31%]	Loss: 0.5944
# accuracy on training set for epoch number 43  0.75375
# epoca
# 43.0
#  time :  4.4151 seconds
# Training [31%]	Loss: 0.5944
# accuracy on training set for epoch number 44  0.7575
# epoca
# 44.0
#  time :  4.5183 seconds
# Training [32%]	Loss: 0.5885
# accuracy on training set for epoch number 45  0.72875
# epoca
# 45.0
#  time :  4.4019 seconds
# Training [33%]	Loss: 0.5874
# accuracy on training set for epoch number 46  0.75375
# epoca
# 46.0
#  time :  4.4150 seconds
# Training [34%]	Loss: 0.5827
# accuracy on training set for epoch number 47  0.75
# epoca
# 47.0
#  time :  4.3601 seconds
# Training [34%]	Loss: 0.5831
# accuracy on training set for epoch number 48  0.76125
# epoca
# 48.0
#  time :  4.6327 seconds
# Training [35%]	Loss: 0.5774
# accuracy on training set for epoch number 49  0.76625
# epoca
# 49.0
#  time :  4.6362 seconds
# Training [36%]	Loss: 0.5741
# accuracy on training set for epoch number 50  0.7625
# epoca
# 50.0
#  time :  4.5246 seconds
# Training [36%]	Loss: 0.5716
# accuracy on training set for epoch number 51  0.7625
# epoca
# 51.0
#  time :  4.4783 seconds
# Training [37%]	Loss: 0.5730
# accuracy on training set for epoch number 52  0.77375
# epoca
# 52.0
#  time :  4.5030 seconds
# Training [38%]	Loss: 0.5687
# accuracy on training set for epoch number 53  0.78125
# epoca
# 53.0
#  time :  4.3668 seconds
# Training [39%]	Loss: 0.5680
# accuracy on training set for epoch number 54  0.78125
# epoca
# 54.0
#  time :  4.4745 seconds
# Training [39%]	Loss: 0.5632
# accuracy on training set for epoch number 55  0.7925
# epoca
# 55.0
#  time :  4.4886 seconds
# Training [40%]	Loss: 0.5585
# accuracy on training set for epoch number 56  0.78375
# epoca
# 56.0
#  time :  4.4455 seconds
# Training [41%]	Loss: 0.5601
# accuracy on training set for epoch number 57  0.7925
# epoca
# 57.0
#  time :  4.3941 seconds
# Training [41%]	Loss: 0.5563
# accuracy on training set for epoch number 58  0.8
# epoca
# 58.0
#  time :  4.5935 seconds
# Training [42%]	Loss: 0.5546
# accuracy on training set for epoch number 59  0.80375
# epoca
# 59.0
#  time :  4.5610 seconds
# Training [43%]	Loss: 0.5539
# accuracy on training set for epoch number 60  0.805
# epoca
# 60.0
#  time :  4.5538 seconds
# Training [44%]	Loss: 0.5507
# accuracy on training set for epoch number 61  0.78375
# epoca
# 61.0
#  time :  4.4166 seconds
# Training [44%]	Loss: 0.5472
# accuracy on training set for epoch number 62  0.7975
# epoca
# 62.0
#  time :  4.4666 seconds
# Training [45%]	Loss: 0.5468
# accuracy on training set for epoch number 63  0.80125
# epoca
# 63.0
#  time :  4.5053 seconds
# Training [46%]	Loss: 0.5439
# accuracy on training set for epoch number 64  0.8
# epoca
# 64.0
#  time :  4.3943 seconds
# Training [46%]	Loss: 0.5424
# accuracy on training set for epoch number 65  0.81625
# epoca
# 65.0
#  time :  4.3780 seconds
# Training [47%]	Loss: 0.5418
# accuracy on training set for epoch number 66  0.8025
# epoca
# 66.0
#  time :  4.4861 seconds
# Training [48%]	Loss: 0.5386
# accuracy on training set for epoch number 67  0.81375
# epoca
# 67.0
#  time :  4.3864 seconds
# Training [49%]	Loss: 0.5373
# accuracy on training set for epoch number 68  0.8025
# epoca
# 68.0
#  time :  4.3830 seconds
# Training [49%]	Loss: 0.5363
# accuracy on training set for epoch number 69  0.815
# epoca
# 69.0
#  time :  4.7329 seconds
# Training [50%]	Loss: 0.5334
# accuracy on training set for epoch number 70  0.815
# epoca
# 70.0
#  time :  4.7071 seconds
# Training [51%]	Loss: 0.5314
# accuracy on training set for epoch number 71  0.81375
# epoca
# 71.0
#  time :  4.7121 seconds
# Training [51%]	Loss: 0.5315
# accuracy on training set for epoch number 72  0.81125
# epoca
# 72.0
#  time :  4.5403 seconds
# Training [52%]	Loss: 0.5264
# accuracy on training set for epoch number 73  0.825
# epoca
# 73.0
#  time :  4.4641 seconds
# Training [53%]	Loss: 0.5270
# accuracy on training set for epoch number 74  0.81875
# epoca
# 74.0
#  time :  4.4762 seconds
# Training [54%]	Loss: 0.5245
# accuracy on training set for epoch number 75  0.8225
# epoca
# 75.0
#  time :  4.5316 seconds
# Training [54%]	Loss: 0.5215
# accuracy on training set for epoch number 76  0.82125
# epoca
# 76.0
#  time :  4.4584 seconds
# Training [55%]	Loss: 0.5206
# accuracy on training set for epoch number 77  0.80125
# epoca
# 77.0
#  time :  4.6148 seconds
# Training [56%]	Loss: 0.5245
# accuracy on training set for epoch number 78  0.82625
# epoca
# 78.0
#  time :  4.7148 seconds
# Training [56%]	Loss: 0.5193
# accuracy on training set for epoch number 79  0.82
# epoca
# 79.0
#  time :  4.3727 seconds
# Training [57%]	Loss: 0.5182
# accuracy on training set for epoch number 80  0.82
# epoca
# 80.0
#  time :  4.4334 seconds
# Training [58%]	Loss: 0.5192
# accuracy on training set for epoch number 81  0.83
# epoca
# 81.0
#  time :  4.4153 seconds
# Training [59%]	Loss: 0.5148
# accuracy on training set for epoch number 82  0.83375
# epoca
# 82.0
#  time :  4.5965 seconds
# Training [59%]	Loss: 0.5141
# accuracy on training set for epoch number 83  0.8375
# epoca
# 83.0
#  time :  4.5839 seconds
# Training [60%]	Loss: 0.5115
# accuracy on training set for epoch number 84  0.83625
# epoca
# 84.0
#  time :  4.5678 seconds
# Training [61%]	Loss: 0.5133
# accuracy on training set for epoch number 85  0.83625
# epoca
# 85.0
#  time :  4.4026 seconds
# Training [61%]	Loss: 0.5094
# accuracy on training set for epoch number 86  0.83625
# epoca
# 86.0
#  time :  4.4529 seconds
# Training [62%]	Loss: 0.5099
# accuracy on training set for epoch number 87  0.84375
# epoca
# 87.0
#  time :  4.5014 seconds
# Training [63%]	Loss: 0.5106
# accuracy on training set for epoch number 88  0.845
# epoca
# 88.0
#  time :  4.4221 seconds
# Training [64%]	Loss: 0.5032
# accuracy on training set for epoch number 89  0.8375
# epoca
# 89.0
#  time :  4.3314 seconds
# Training [64%]	Loss: 0.5027
# accuracy on training set for epoch number 90  0.82875
# epoca
# 90.0
#  time :  4.3470 seconds
# Training [65%]	Loss: 0.5062
# accuracy on training set for epoch number 91  0.84
# epoca
# 91.0
#  time :  4.4696 seconds
# Training [66%]	Loss: 0.5055
# accuracy on training set for epoch number 92  0.835
# epoca
# 92.0
#  time :  4.6314 seconds
# Training [66%]	Loss: 0.5057
# accuracy on training set for epoch number 93  0.8475
# epoca
# 93.0
#  time :  4.6487 seconds
# Training [67%]	Loss: 0.5005
# accuracy on training set for epoch number 94  0.845
# epoca
# 94.0
#  time :  4.7744 seconds
# Training [68%]	Loss: 0.4997
# accuracy on training set for epoch number 95  0.84
# epoca
# 95.0
#  time :  4.4168 seconds
# Training [69%]	Loss: 0.5042
# accuracy on training set for epoch number 96  0.83875
# epoca
# 96.0
#  time :  4.4827 seconds
# Training [69%]	Loss: 0.4977
# accuracy on training set for epoch number 97  0.83125
# epoca
# 97.0
#  time :  4.2033 seconds
# Training [70%]	Loss: 0.4981
# accuracy on training set for epoch number 98  0.84375
# epoca
# 98.0
#  time :  4.3962 seconds
# Training [71%]	Loss: 0.5009
# accuracy on training set for epoch number 99  0.83875
# epoca
# 99.0
#  time :  4.4334 seconds
# Training [71%]	Loss: 0.4954
# accuracy on training set for epoch number 100  0.8525
# epoca
# 100.0
#  time :  4.3157 seconds
# Training [72%]	Loss: 0.4934
# accuracy on training set for epoch number 101  0.84375
# epoca
# 101.0
#  time :  4.5415 seconds
# Training [73%]	Loss: 0.4966
# accuracy on training set for epoch number 102  0.855
# epoca
# 102.0
#  time :  4.5256 seconds
# Training [74%]	Loss: 0.4920
# accuracy on training set for epoch number 103  0.85625
# epoca
# 103.0
#  time :  4.5398 seconds
# Training [74%]	Loss: 0.4921
# accuracy on training set for epoch number 104  0.855
# epoca
# 104.0
#  time :  4.4085 seconds
# Training [75%]	Loss: 0.4957
# accuracy on training set for epoch number 105  0.8525
# epoca
# 105.0
#  time :  4.4495 seconds
# Training [76%]	Loss: 0.4944
# accuracy on training set for epoch number 106  0.85625
# epoca
# 106.0
#  time :  4.4931 seconds
# Training [76%]	Loss: 0.4872
# accuracy on training set for epoch number 107  0.85625
# epoca
# 107.0
#  time :  4.6008 seconds
# Training [77%]	Loss: 0.4883
# accuracy on training set for epoch number 108  0.8625
# epoca
# 108.0
#  time :  4.3773 seconds
# Training [78%]	Loss: 0.4867
# accuracy on training set for epoch number 109  0.85
# epoca
# 109.0
#  time :  4.6997 seconds
# Training [79%]	Loss: 0.4874
# accuracy on training set for epoch number 110  0.85625
# epoca
# 110.0
#  time :  4.5936 seconds
# Training [79%]	Loss: 0.4832
# accuracy on training set for epoch number 111  0.86125
# epoca
# 111.0
#  time :  4.6088 seconds
# Training [80%]	Loss: 0.4834
# accuracy on training set for epoch number 112  0.86375
# epoca
# 112.0
#  time :  4.7095 seconds
# Training [81%]	Loss: 0.4854
# accuracy on training set for epoch number 113  0.86125
# epoca
# 113.0
#  time :  4.8267 seconds
# Training [81%]	Loss: 0.4869
# accuracy on training set for epoch number 114  0.85375
# epoca
# 114.0
#  time :  4.5546 seconds
# Training [82%]	Loss: 0.4879
# accuracy on training set for epoch number 115  0.86375
# epoca
# 115.0
#  time :  4.6275 seconds
# Training [83%]	Loss: 0.4801
# accuracy on training set for epoch number 116  0.8525
# epoca
# 116.0
#  time :  4.7527 seconds
# Training [84%]	Loss: 0.4819
# accuracy on training set for epoch number 117  0.8675
# epoca
# 117.0
#  time :  4.6257 seconds
# Training [84%]	Loss: 0.4865
# accuracy on training set for epoch number 118  0.845
# epoca
# 118.0
#  time :  4.4641 seconds
# Training [85%]	Loss: 0.4798
# accuracy on training set for epoch number 119  0.86625
# epoca
# 119.0
#  time :  4.3476 seconds
# Training [86%]	Loss: 0.4798
# accuracy on training set for epoch number 120  0.86375
# epoca
# 120.0
#  time :  4.5145 seconds
# Training [86%]	Loss: 0.4761
# accuracy on training set for epoch number 121  0.87125
# epoca
# 121.0
#  time :  4.3935 seconds
# Training [87%]	Loss: 0.4817
# accuracy on training set for epoch number 122  0.86875
# epoca
# 122.0
#  time :  4.5016 seconds
# Training [88%]	Loss: 0.4793
# accuracy on training set for epoch number 123  0.87125
# epoca
# 123.0
#  time :  4.4262 seconds
# Training [89%]	Loss: 0.4762
# accuracy on training set for epoch number 124  0.8575
# epoca
# 124.0
#  time :  4.4817 seconds
# Training [89%]	Loss: 0.4754
# accuracy on training set for epoch number 125  0.8675
# epoca
# 125.0
#  time :  4.3553 seconds
# Training [90%]	Loss: 0.4771
# accuracy on training set for epoch number 126  0.8675
# epoca
# 126.0
#  time :  4.6218 seconds
# Training [91%]	Loss: 0.4746
# accuracy on training set for epoch number 127  0.85875
# epoca
# 127.0
#  time :  4.4993 seconds
# Training [91%]	Loss: 0.4724
# accuracy on training set for epoch number 128  0.85875
# epoca
# 128.0
#  time :  4.4301 seconds
# Training [92%]	Loss: 0.4737
# accuracy on training set for epoch number 129  0.8675
# epoca
# 129.0
#  time :  4.2819 seconds
# Training [93%]	Loss: 0.4711
# accuracy on training set for epoch number 130  0.87125
# epoca
# 130.0
#  time :  4.5620 seconds
# Training [94%]	Loss: 0.4720
# accuracy on training set for epoch number 131  0.87125
# epoca
# 131.0
#  time :  4.4323 seconds
# Training [94%]	Loss: 0.4733
# accuracy on training set for epoch number 132  0.875
# epoca
# 132.0
#  time :  4.5676 seconds
# Training [95%]	Loss: 0.4722
# accuracy on training set for epoch number 133  0.8775
# epoca
# 133.0
#  time :  4.3958 seconds
# Training [96%]	Loss: 0.4691
# accuracy on training set for epoch number 134  0.87875
# epoca
# 134.0
#  time :  4.4594 seconds
# Training [96%]	Loss: 0.4694
# accuracy on training set for epoch number 135  0.86625
# epoca
# 135.0
#  time :  4.5126 seconds
# Training [97%]	Loss: 0.4743
# accuracy on training set for epoch number 136  0.84875
# epoca
# 136.0
#  time :  4.3517 seconds
# Training [98%]	Loss: 0.4664
# accuracy on training set for epoch number 137  0.88
# epoca
# 137.0
#  time :  4.4145 seconds
# Training [99%]	Loss: 0.4689
# accuracy on training set for epoch number 138  0.86625
# epoca
# 138.0
#  time :  4.2684 seconds
# Training [99%]	Loss: 0.4683
# accuracy on training set for epoch number 139  0.86875
# epoca
# 139.0
#  time :  4.3960 seconds
# Training [100%]	Loss: 0.4686
# accuracy on training set for epoch number 140  0.8825

# %%
print(len(train_lossesq))
print(len(val_lossesq))
# Out:
# 140
# 140

# %%
# plotting the training and validation loss
#GRAPHS

#------loss-validation/training-----
plt.plot(train_lossesq, label='Training loss')
plt.plot(val_lossesq, label='Validation loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss function')
plt.title("Hybrid NN Convergence")
#plt.yscale("log")
plt.savefig(model_folder+model_name+"LVThybrid.png")
plt.show()
#------loss-validation---------

plt.figure()
plt.title('Hybrid training loss')
plt.plot(train_lossesq, label='Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss function')
#plt.savefig(hybridModelFolder+hybridModelName+"LThybrid.png")
plt.show()
#------accuracies-training--------
plt.figure()
plt.plot(accuracyTrainLossesq, label='Accuracy training')
plt.xlabel('Epochs')
plt.ylabel('Loss function')
plt.title('Hybrid accuracies')
plt.savefig(model_folder+model_name+"AThybrid.png")
plt.show()
#-----total-----
plt.figure()
plt.title('Hybrid Training Loss/Accuracies')
plt.plot(train_lossesq, label='Training loss')
plt.plot(accuracyTrainLossesq, label='Training accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss function')
plt.savefig(model_folder+model_name+"ALTVhybrid.png")
plt.show()
# Out:
# [0.692840454755006, 0.688308267681687, 0.6855353161140725, 0.6832210355334811, 0.6808908184369405, 0.6790734728177389, 0.6769128684644345, 0.6741424953496015, 0.672855156439322, 0.6712311108907064, 0.6696084914384065, 0.6688889044302481, 0.6661712218213964, 0.6637654172049628, 0.6626723497002213, 0.659671684106191, 0.6583440921924733, 0.6564140121142069, 0.6553627870700978, 0.6518113127461186, 0.6505721741252475, 0.6482138170136346, 0.6459217645503856, 0.6429645419120789, 0.6415415825667204, 0.6390267610549927, 0.6378159699616609, 0.6353328338375798, 0.6321647984010202, 0.6288653744591607, 0.6261588048051905, 0.6253737696894893, 0.6188515292273628, 0.6194853208683155, 0.616060440187101, 0.6138331117453398, 0.6121188755388614, 0.6080600950453017, 0.6075754011118853, 0.6036117518389666, 0.5994977045942236, 0.5965372456444634, 0.5944338683728818, 0.5943792992168002, 0.5884520014127096, 0.5874245762825012, 0.5827314036863821, 0.5831274809660735, 0.5773880305113616, 0.5740810191189801, 0.5716177931538334, 0.5729576238879451, 0.5687322086758084, 0.5680215767136326, 0.5631894204351637, 0.5585242487766124, 0.5601180571096914, 0.5562592855206242, 0.5545603445282689, 0.5539310629721041, 0.5507178825360758, 0.5471934013896518, 0.5467803025687182, 0.5438706013891432, 0.5424178938070933, 0.5417903562386831, 0.5386296234748982, 0.5373184349801805, 0.5362981734452424, 0.53338713116116, 0.5314041464417069, 0.5314685614020737, 0.5263536473115286, 0.5270131804324962, 0.5244700025629114, 0.521472555619699, 0.5206248969943436, 0.5244909171704892, 0.5192645997912796, 0.5181904700067308, 0.5192075040605333, 0.5148135478849765, 0.5140945690649527, 0.5115327393567121, 0.5132530055664204, 0.5093899269898733, 0.5099094918480626, 0.5106489007119779, 0.5031719141536288, 0.5026912247693097, 0.5061665585747471, 0.5055226451820798, 0.5056752363840739, 0.5004740037299968, 0.49965271574479564, 0.5041734487922104, 0.4977090027597215, 0.49812591738171047, 0.500857800245285, 0.4954174006426776, 0.4934216053397567, 0.4966222919799663, 0.49195171064800686, 0.49205778152854357, 0.49571708065492137, 0.49442649991424, 0.4872255645416401, 0.48825604496178804, 0.48668264459680627, 0.4874413421860448, 0.48320639464590287, 0.48343823905344363, 0.4854078005861353, 0.4868858611142194, 0.48785237029746725, 0.4800822028407344, 0.4819138723391074, 0.4864843057261573, 0.4798119134373135, 0.47981054915322197, 0.4761117387700964, 0.4817137806503861, 0.4793080742712374, 0.47616092915888186, 0.4754397228912071, 0.47711311446295845, 0.4746219504762579, 0.47242092975863703, 0.47367097713329176, 0.4711194468869103, 0.4720125948941266, 0.4732929942784486, 0.47216422469527636, 0.46906759672694737, 0.4693910810682509, 0.47428836094008553, 0.46636853284305996, 0.4689050206431636, 0.4683305091328091, 0.4685920112662845]

# %%
scores_train = torch.sigmoid(model4(trainSetTorch))[:,0]
scores_val = torch.sigmoid(model4(validationSetTorch))[:,0]

predictions_train = scores_train > 0.5
predictions_val = scores_val > 0.5
accuracy_train = (predictions_train == trainLabelsTorch).sum()/ trainLabelsTorch.shape[0]
accuracy_val = (predictions_val == validationLabelsTorch).sum()/ validationLabelsTorch.shape[0]

print("accuracy on training set: ", accuracy_train.numpy())
print("accuracy on validation set: ", accuracy_val.numpy())
# Out:
# accuracy on training set:  0.8825
# accuracy on validation set:  0.785

# %%
accuraciesLoss=[]

# %%
# Saving data
with open(model_folder + model_name + ".txt", 'w') as fp:
    # Writing training losses
    fp.write("train_losses hybrid:\n\n")
    fp.writelines("%s\n" % item for item in train_lossesq)
    print('Train losses saved')

    # Writing validation losses
    fp.write("\nval_losses hybrid:\n\n")
    fp.writelines("%s\n" % item for item in val_lossesq)
    print('Val losses saved')

    # Writing accuracies
    fp.write("\naccuracies hybrid:\n\n")
    fp.writelines("%s\n" % item for item in accuracyTrainLossesq)
    print('Accuracies saved')

    # Writing accuracy on training
    fp.write("\naccuracy on training HYBRID:")
    fp.write(str(accuracy_train.numpy()))
    print('Accuracy on training saved')

    # Writing accuracy on validation
    fp.write("\naccuracy on validation HYBRID:")
    fp.write(str(accuracy_val.numpy()))
    print('Accuracy on validation saved')

# Saving the hybrid model
torch.save(model4, model_folder + model_name + "Hybrid.pt")
print('Hybrid model saved')
# Out:
# Done
# Done
# Done

# %%
hybridModel = torch.load(model_folder+model_name+"Hybrid.pt")

# %%
scores_val = torch.sigmoid(hybridModel(validationSetTorch))[:,0]
predictions_val = scores_val > 0.5
accuracy_val = (predictions_val == validationLabelsTorch).sum()/ validationLabelsTorch.shape[0]

# %%
print("accuracy on validation set: ", accuracy_val.numpy())
# Out:
# accuracy on validation set:  0.785

# %%
#--------test part---------
import funForTest as fun2
parasitized_images=fun2.load_images("../DatasetTest/pTest/")
uninfected_images=fun2.load_images('../DatasetTest/uTest/')
test_set,test_lb=fun2.create_2_subsets(parasitized_images,uninfected_images,42)
test_set_torch  = torch.from_numpy(test_set).float()
test_lb_torch  = torch.from_numpy(test_lb).float()
    
#convert data to Torch tensor type (annoying but necessary)

print(len(test_set_torch))
scores_test = torch.sigmoid(hybridModel(test_set_torch))[:,0]
predictions_test = scores_test > 0.5
accuracy_test = (predictions_test == test_lb_torch).sum()/ test_lb_torch.shape[0]
print("accuracy on test set: ", accuracy_test.numpy())
# Out:
# mioDataSetTest/pTest/
# mioDataSetTest/uTest/
# 400
# accuracy on test set:  0.775
